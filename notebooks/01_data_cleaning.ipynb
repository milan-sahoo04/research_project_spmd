# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_data.csv")
print(df.head())
# Out:
#                                                 text  label
# 0  the operation of coalfired power plants caused...      1
# 1  biomass burning and residential coal use incre...      2
# 2  low wind speed trapped pollutants near the sur...      3
# 3  coal power plants and residential fuel use tog...      4

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(
    df,
    test_size=0.30,
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42
)

print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))
# Out:
# Train size: 2
# Validation size: 1
# Test size: 1

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['text', 'label'], dtype='str')
#                                                 text  label
# 0  the operation of coalfired power plants caused...      1
# 1  biomass burning and residential coal use incre...      2
# 2  low wind speed trapped pollutants near the sur...      3
# 3  coal power plants and residential fuel use tog...      4
